# %%
import pandas as pd

# %%
df = pd.read_csv("dfTransjakarta180kRows.csv")

df.head(10)
# Out:
#           transID            payCardID payCardBank  \
# 0  VRPJ892P3M98RA     3561407960318444         dki
# 1  ZWCH834I6M26HS      347728053419394      emoney
# 2  YRLD835V6L82GO      377105453850671      emoney
# 3  ZZBX143N6N83HQ     4486493302356581         dki
# 4  EWEG491A2W45DR       30139379978125         bni
# 5  KTGG277R2I90ZB       30394281967910         bni
# 6  VSJU956Z4T24LI     4974829151599657         dki
# 7  HBMD368H3K77KW     3532177104809428         dki
# 8  SQHG432Q6Z10BR     3537522260639116         dki
# 9  EHWL093H6L20UL  4677151756111287186      brizzi
#
#                       payCardName payCardSex  payCardBirthDate corridorID  \
# 0     Dr. Janet Nashiruddin, M.Ak          M              2010          4
# 1               Balamantri Rahayu          M              2002     JAK.28
# 2                    Dian Mustofa          F              1993        B13
# 3        Cut Janet Suryatmi, M.Ak          M              1980         8K
# 4  dr. Mulyanto Pudjiastuti, M.Ak          F              1997        NaN
# 5           Dasa Prakasa, S.I.Kom          F              1993    JAK.117
# 6                  Elvina Hasanah          M              1966         9F
# 7           Perkasa Prakasa, M.Pd          F              2011     JAK.31
# 8                    Ayu Wahyudin          F              2009     JAK.37
# 9       H. Xanana Santoso, S.Farm          M              2010     JAK.15
#
#                         corridorName  direction tapInStops  ... tapInStopsLon  \
# 0             Pulo Gadung 2 - Tosari        1.0     P00167  ...     106.89165
# 1    Kp. Rambutan - Taman Wiladatika        1.0    B04633P  ...     106.86298
# 2              Bekasi Barat - Blok M        1.0    B02192P  ...     106.99215
# 3                  Batusari - Grogol        1.0    B03637P  ...     106.78213
# 4                                NaN        0.0        NaN  ...     106.83514
# 5      Tanjung Priok - Tanah Merdeka        1.0    B04272P  ...     106.89638
# 6              Rusun Tambora - Pluit        0.0     P00090  ...     106.79352
# 7                    Blok M - Andara        0.0    B00042P  ...     106.80369
# 8  Cililitan - Condet via Kayu Manis        1.0    B05218P  ...     106.85862
# 9         Bulak Turi - Tanjung Priok        0.0    B01327P  ...     106.89550
#
#    stopStartSeq            tapInTime  tapOutStops  \
# 0            12  2023-04-03 06:53:02       P00127
# 1            27  2023-04-03 05:59:19      B00865P
# 2             6  2023-04-03 05:13:24      B00108P
# 3            16  2023-04-03 05:20:24          NaN
# 4             2  2023-04-03 06:00:54      B02755P
# 5            17  2023-04-03 05:06:00      B04818P
# 6             5  2023-04-03 06:21:07       P00170
# 7            55  2023-04-03 06:34:03      B01147P
# 8            10  2023-04-03 05:48:17      B00405P
# 9            46  2023-04-03 05:09:13      B05728P
#
#                 tapOutStopsName tapOutStopsLat tapOutStopsLon  stopEndSeq  \
# 0                         Layur      -6.193539      106.89909        13.0
# 1                 Jln. Ar Ridho      -6.308148      106.86935        30.0
# 2        Bandar Djakarta Bekasi      -6.227085      106.99683         9.0
# 3        Yayasan Alkahfi Jakbar      -6.198896      106.76889        26.0
# 4         Perpustakaan Nasional      -6.180673      106.82643         5.0
# 5       Simpang Gotong Royong 2      -6.125482      106.89331        21.0
# 6                   Penjaringan      -6.126306      106.79203         7.0
# 7  Jln. H. Terin Pangkalan Jati      -6.327961      106.80054        56.0
# 8           Gg. Ani Raya Condet      -6.266674      106.86054        37.0
# 9             Term. Tj. Priok 1      -6.109800      106.88118        52.0
#
#             tapOutTime  payAmount
# 0  2023-04-03 07:13:28     3500.0
# 1  2023-04-03 06:57:06        0.0
# 2  2023-04-03 06:01:23    20000.0
# 3  2023-04-03 06:01:25     3500.0
# 4  2023-04-03 06:47:32     3500.0
# 5  2023-04-03 05:41:04        0.0
# 6  2023-04-03 06:52:58        0.0
# 7  2023-04-03 07:32:53        0.0
# 8  2023-04-03 06:13:38        0.0
# 9  2023-04-03 06:07:24        0.0
#
# [10 rows x 22 columns]

# %%
# Hitung titik tengah
mid = len(df) // 2

# %%
# Bagi jadi dua
df_part1 = df.iloc[:mid]
df_part2 = df.iloc[mid:]

# Simpan ke file baru
df_part1.to_csv("data_transjakarta_1.csv", index=False)
df_part2.to_csv("data_transjakarta_2.csv", index=False)

print("File berhasil dibagi jadi 2")
# Out:
# File berhasil dibagi jadi 2

# %%
df1 = pd.read_csv("data_transjakarta_1.csv")
df1
# Out:
#               transID            payCardID payCardBank  \
# 0      VRPJ892P3M98RA     3561407960318444         dki
# 1      ZWCH834I6M26HS      347728053419394      emoney
# 2      YRLD835V6L82GO      377105453850671      emoney
# 3      ZZBX143N6N83HQ     4486493302356581         dki
# 4      EWEG491A2W45DR       30139379978125         bni
# ...               ...                  ...         ...
# 94745  AYUG731J7I15WP  4060675934254982980      brizzi
# 94746  HHNG563Z3T52MJ      180068294800346      emoney
# 94747  UNAW036H5S18ZV     4794628463414177         dki
# 94748  DTJC918C2H41UF         503821322016       flazz
# 94749  ESSK971T3J36AQ      213100007061782      emoney
#
#                           payCardName payCardSex  payCardBirthDate corridorID  \
# 0         Dr. Janet Nashiruddin, M.Ak          M              2010          4
# 1                   Balamantri Rahayu          M              2002     JAK.28
# 2                        Dian Mustofa          F              1993        B13
# 3            Cut Janet Suryatmi, M.Ak          M              1980         8K
# 4      dr. Mulyanto Pudjiastuti, M.Ak          F              1997        NaN
# ...                               ...        ...               ...        ...
# 94745                 Drs. Hani Utama          M              1983         1C
# 94746                Fathonah Wahyuni          F              1986        12B
# 94747                    Dasa Sitorus          F              2009         3A
# 94748                   Nalar Damanik          M              1992     JAK.12
# 94749               Safina Nainggolan          F              2002       JIS3
#
#                                          corridorName  direction tapInStops  \
# 0                              Pulo Gadung 2 - Tosari        1.0     P00167
# 1                     Kp. Rambutan - Taman Wiladatika        1.0    B04633P
# 2                               Bekasi Barat - Blok M        1.0    B02192P
# 3                                   Batusari - Grogol        1.0    B03637P
# 4                                                 NaN        0.0        NaN
# ...                                               ...        ...        ...
# 94745                           Pesanggrahan - Blok M        0.0     P00045
# 94746                                   Pluit - Senen        0.0    B02886P
# 94747                       Rusun Pesakih - Kalideres        0.0    B03286P
# 94748  Tanah Abang - Kebayoran Lama via Pos Pengumben        0.0    B05221P
# 94749         Harmoni - Jakarta International Stadium        0.0     P00046
#
#        ... tapInStopsLon  stopStartSeq            tapInTime  tapOutStops  \
# 0      ...     106.89165            12  2023-04-03 06:53:02       P00127
# 1      ...     106.86298            27  2023-04-03 05:59:19      B00865P
# 2      ...     106.99215             6  2023-04-03 05:13:24      B00108P
# 3      ...     106.78213            16  2023-04-03 05:20:24          NaN
# 4      ...     106.83514             2  2023-04-03 06:00:54      B02755P
# ...    ...           ...           ...                  ...          ...
# 94745  ...     106.79783            34  2023-04-11 21:13:01      B06577P
# 94746  ...     106.79090             0  2023-04-11 19:24:14      B05324P
# 94747  ...     106.71698             0  2023-04-11 18:08:28      B02379P
# 94748  ...     106.77024            41  2023-04-11 19:21:21      B04896P
# 94749  ...     106.85805             8  2023-04-11 21:30:53       P00291
#
#                     tapOutStopsName tapOutStopsLat tapOutStopsLon  stopEndSeq  \
# 0                             Layur      -6.193539     106.899090        13.0
# 1                     Jln. Ar Ridho      -6.308148     106.869350        30.0
# 2            Bandar Djakarta Bekasi      -6.227085     106.996830         9.0
# 3            Yayasan Alkahfi Jakbar      -6.198896     106.768890        26.0
# 4             Perpustakaan Nasional      -6.180673     106.826430         5.0
# ...                             ...            ...            ...         ...
# 94745                Blok M Jalur 2      -6.243369     106.801880        35.0
# 94746                       SMKN 56      -6.119094     106.794230         1.0
# 94747  Masjid Raya KH Hasyim Asyari      -6.159272     106.717080         1.0
# 94748  Simpang Kampung Baru Assirat      -6.225618     106.771940        49.0
# 94749            Harmoni Arah Utara      -6.162678     106.819663        13.0
#
#                 tapOutTime  payAmount
# 0      2023-04-03 07:13:28     3500.0
# 1      2023-04-03 06:57:06        0.0
# 2      2023-04-03 06:01:23    20000.0
# 3      2023-04-03 06:01:25     3500.0
# 4      2023-04-03 06:47:32     3500.0
# ...                    ...        ...
# 94745  2023-04-11 22:53:40     3500.0
# 94746  2023-04-11 20:45:37     3500.0
# 94747  2023-04-11 19:13:55        0.0
# 94748  2023-04-11 20:22:27        0.0
# 94749  2023-04-11 23:12:54     3500.0
#
# [94750 rows x 22 columns]

# %%
df2 = pd.read_csv("data_transjakarta_2.csv")
df2
# Out:
#               transID            payCardID payCardBank  \
# 0      ZJYB898V9R98ED  4897528453581548947      brizzi
# 1      DLBW159R6E00GH     4701047998022938         dki
# 2      WIDX220R5X91AV     3555473824753729         dki
# 3      IQAQ948D4T09YX      342036975037954      emoney
# 4      GDCW629Y9I61QQ     3594586987402215         dki
# ...               ...                  ...         ...
# 94745  AEQP180C2Q77IS      378254320267609      emoney
# 94746  PJOF006Z8Q63II     5406087682675422         dki
# 94747  NTSG621H8U49WW  4674674527076302608      brizzi
# 94748  PUNA543S2M10LX        4952762933693      online
# 94749  NRUZ377L2D82PG     2235668090485688         dki
#
#                       payCardName payCardSex  payCardBirthDate corridorID  \
# 0                  Banawa Mandala          F              1990          8
# 1       R.A. Laras Pangestu, S.IP          F              2006        M1H
# 2           Rahman Palastri, S.Pd          M              1977        D21
# 3                  Lantar Jailani          M              1992     JAK.77
# 4                  Yulia Yuliarti          M              2005        11C
# ...                           ...        ...               ...        ...
# 94745  R.A. Malika Samosir, S.Kom          M              1998    JAK.43B
# 94746              Amalia Gunarto          M              1981         9C
# 94747       R.A. Lintang Wibisono          F              1998         6T
# 94748             Yunita Sitompul          F              1984          2
# 94749                 Omar Rahayu          M              1997         8C
#
#                                      corridorName  direction tapInStops  ...  \
# 0             Lebak Bulus - Pasar Baru via Tomang        1.0     P00176  ...
# 1                    Tanah Abang - St. Gondangdia        1.0    B05666P  ...
# 2             Universitas Indonesia - Lebak Bulus        1.0    B00132P  ...
# 3                   Tanjung Priok - Jembatan Item        0.0    B01954P  ...
# 4            Rusun Pinus Elok - Rusun Pulo Gebang        1.0    B00081P  ...
# ...                                           ...        ...        ...  ...
# 94745  Tongtek - Tebet Eco Park (TEP) - Cililitan        1.0    B06271P  ...
# 94746             Pinang Ranti - Bundaran Senayan        1.0     P00040  ...
# 94747                       Pasar Minggu - Velbak        1.0    B06746P  ...
# 94748                         Pulo Gadung - Monas        1.0     P00005  ...
# 94749                Kebayoran Lama - Tanah Abang        1.0    B02196P  ...
#
#       tapInStopsLon  stopStartSeq            tapInTime  tapOutStops  \
# 0        106.816980             3  2023-04-11 20:10:01       P00187
# 1        106.814090             3  2023-04-11 21:13:59      B05445P
# 2        106.786360             5  2023-04-11 19:39:48      B01405P
# 3        106.881300            46  2023-04-11 17:36:39      B03179P
# 4        106.938030             8  2023-04-11 19:24:21      B02800P
# ...             ...           ...                  ...          ...
# 94745    106.852860            24  2023-04-02 13:00:49      B03318P
# 94746    106.858140             9  2023-04-04 17:31:55       P00030
# 94747    106.808665            17  2023-04-05 10:37:19      B06750P
# 94748    106.888800            12  2023-04-14 13:34:20       P00192
# 94749    106.814530            12  2023-04-29 09:14:32      B05223P
#
#                   tapOutStopsName tapOutStopsLat tapOutStopsLon  stopEndSeq  \
# 0                   Pos Pengumben      -6.212935     106.772260        14.0
# 1                St. Gondangdia 2      -6.185054     106.832300        11.0
# 2                    Jln. Muara 1      -6.304063     106.850610        19.0
# 3          RS Sukmul Sisma Medika      -6.112315     106.882360        47.0
# 4                     Perum Tpi 1      -6.197379     106.935130        14.0
# ...                           ...            ...            ...         ...
# 94745             Sawo Kecik Raya      -6.224852     106.854890        34.0
# 94746  Cawang Ciliwung Arah Timur      -6.243012     106.863540        10.0
# 94747  Sbr. SDN Cilandak Barat 15      -6.288628     106.806811        19.0
# 94748               Pulo Gadung 1      -6.183239     106.909070        15.0
# 94749                   Simprug 1      -6.223678     106.790200        28.0
#
#                 tapOutTime  payAmount
# 0      2023-04-11 21:16:37     3500.0
# 1      2023-04-11 22:56:10        NaN
# 2      2023-04-11 20:56:09     3500.0
# 3      2023-04-11 18:31:29        0.0
# 4      2023-04-11 20:30:46        0.0
# ...                    ...        ...
# 94745  2023-04-02 14:54:30        0.0
# 94746  2023-04-04 18:38:31     3500.0
# 94747  2023-04-05 12:20:28     3500.0
# 94748  2023-04-14 16:05:12     3500.0
# 94749  2023-04-29 11:53:39     3500.0
#
# [94750 rows x 22 columns]

# %%
df.T
# Out:
#                                        0       \
# transID                        VRPJ892P3M98RA
# payCardID                    3561407960318444
# payCardBank                               dki
# payCardName       Dr. Janet Nashiruddin, M.Ak
# payCardSex                                  M
# payCardBirthDate                         2010
# corridorID                                  4
# corridorName           Pulo Gadung 2 - Tosari
# direction                                 1.0
# tapInStops                             P00167
# tapInStopsName              Pemuda Rawamangun
# tapInStopsLat                       -6.193488
# tapInStopsLon                       106.89165
# stopStartSeq                               12
# tapInTime                 2023-04-03 06:53:02
# tapOutStops                            P00127
# tapOutStopsName                         Layur
# tapOutStopsLat                      -6.193539
# tapOutStopsLon                      106.89909
# stopEndSeq                               13.0
# tapOutTime                2023-04-03 07:13:28
# payAmount                              3500.0
#
#                                            1                       2       \
# transID                            ZWCH834I6M26HS          YRLD835V6L82GO
# payCardID                         347728053419394         377105453850671
# payCardBank                                emoney                  emoney
# payCardName                     Balamantri Rahayu            Dian Mustofa
# payCardSex                                      M                       F
# payCardBirthDate                             2002                    1993
# corridorID                                 JAK.28                     B13
# corridorName      Kp. Rambutan - Taman Wiladatika   Bekasi Barat - Blok M
# direction                                     1.0                     1.0
# tapInStops                                B04633P                 B02192P
# tapInStopsName         Sekolah Islam PB Soedirman       Mall Metropolitan
# tapInStopsLat                           -6.314293               -6.247861
# tapInStopsLon                           106.86298               106.99215
# stopStartSeq                                   27                       6
# tapInTime                     2023-04-03 05:59:19     2023-04-03 05:13:24
# tapOutStops                               B00865P                 B00108P
# tapOutStopsName                     Jln. Ar Ridho  Bandar Djakarta Bekasi
# tapOutStopsLat                          -6.308148               -6.227085
# tapOutStopsLon                          106.86935               106.99683
# stopEndSeq                                   30.0                     9.0
# tapOutTime                    2023-04-03 06:57:06     2023-04-03 06:01:23
# payAmount                                     0.0                 20000.0
#
#                                          3       \
# transID                          ZZBX143N6N83HQ
# payCardID                      4486493302356581
# payCardBank                                 dki
# payCardName            Cut Janet Suryatmi, M.Ak
# payCardSex                                    M
# payCardBirthDate                           1980
# corridorID                                   8K
# corridorName                  Batusari - Grogol
# direction                                   1.0
# tapInStops                              B03637P
# tapInStopsName    Sbr. Jln. Angsana Kemanggisan
# tapInStopsLat                         -6.194813
# tapInStopsLon                         106.78213
# stopStartSeq                                 16
# tapInTime                   2023-04-03 05:20:24
# tapOutStops                                 NaN
# tapOutStopsName          Yayasan Alkahfi Jakbar
# tapOutStopsLat                        -6.198896
# tapOutStopsLon                        106.76889
# stopEndSeq                                 26.0
# tapOutTime                  2023-04-03 06:01:25
# payAmount                                3500.0
#
#                                           4       \
# transID                           EWEG491A2W45DR
# payCardID                         30139379978125
# payCardBank                                  bni
# payCardName       dr. Mulyanto Pudjiastuti, M.Ak
# payCardSex                                     F
# payCardBirthDate                            1997
# corridorID                                   NaN
# corridorName                                 NaN
# direction                                    0.0
# tapInStops                                   NaN
# tapInStopsName                       BRI Menteng
# tapInStopsLat                          -6.186792
# tapInStopsLon                          106.83514
# stopStartSeq                                   2
# tapInTime                    2023-04-03 06:00:54
# tapOutStops                              B02755P
# tapOutStopsName            Perpustakaan Nasional
# tapOutStopsLat                         -6.180673
# tapOutStopsLon                         106.82643
# stopEndSeq                                   5.0
# tapOutTime                   2023-04-03 06:47:32
# payAmount                                 3500.0
#
#                                          5                      6       \
# transID                          KTGG277R2I90ZB         VSJU956Z4T24LI
# payCardID                        30394281967910       4974829151599657
# payCardBank                                 bni                    dki
# payCardName               Dasa Prakasa, S.I.Kom         Elvina Hasanah
# payCardSex                                    F                      M
# payCardBirthDate                           1993                   1966
# corridorID                              JAK.117                     9F
# corridorName      Tanjung Priok - Tanah Merdeka  Rusun Tambora - Pluit
# direction                                   1.0                    0.0
# tapInStops                              B04272P                 P00090
# tapInStopsName     Sbr. RPTRA Radar Pembangunan           Jembatan Dua
# tapInStopsLat                         -6.120126              -6.143279
# tapInStopsLon                         106.89638              106.79352
# stopStartSeq                                 17                      5
# tapInTime                   2023-04-03 05:06:00    2023-04-03 06:21:07
# tapOutStops                             B04818P                 P00170
# tapOutStopsName         Simpang Gotong Royong 2            Penjaringan
# tapOutStopsLat                        -6.125482              -6.126306
# tapOutStopsLon                        106.89331              106.79203
# stopEndSeq                                 21.0                    7.0
# tapOutTime                  2023-04-03 05:41:04    2023-04-03 06:52:58
# payAmount                                   0.0                    0.0
#
#                                         7       \
# transID                         HBMD368H3K77KW
# payCardID                     3532177104809428
# payCardBank                                dki
# payCardName              Perkasa Prakasa, M.Pd
# payCardSex                                   F
# payCardBirthDate                          2011
# corridorID                              JAK.31
# corridorName                   Blok M - Andara
# direction                                  0.0
# tapInStops                             B00042P
# tapInStopsName             Andara Margasatwa 1
# tapInStopsLat                        -6.313471
# tapInStopsLon                        106.80369
# stopStartSeq                                55
# tapInTime                  2023-04-03 06:34:03
# tapOutStops                            B01147P
# tapOutStopsName   Jln. H. Terin Pangkalan Jati
# tapOutStopsLat                       -6.327961
# tapOutStopsLon                       106.80054
# stopEndSeq                                56.0
# tapOutTime                 2023-04-03 07:32:53
# payAmount                                  0.0
#
#                                              8       \
# transID                              SQHG432Q6Z10BR
# payCardID                          3537522260639116
# payCardBank                                     dki
# payCardName                            Ayu Wahyudin
# payCardSex                                        F
# payCardBirthDate                               2009
# corridorID                                   JAK.37
# corridorName      Cililitan - Condet via Kayu Manis
# direction                                       1.0
# tapInStops                                  B05218P
# tapInStopsName                  Simpang Waru Tengah
# tapInStopsLat                             -6.293301
# tapInStopsLon                             106.85862
# stopStartSeq                                     10
# tapInTime                       2023-04-03 05:48:17
# tapOutStops                                 B00405P
# tapOutStopsName                 Gg. Ani Raya Condet
# tapOutStopsLat                            -6.266674
# tapOutStopsLon                            106.86054
# stopEndSeq                                     37.0
# tapOutTime                      2023-04-03 06:13:38
# payAmount                                       0.0
#
#                                       9       ...                      189490  \
# transID                       EHWL093H6L20UL  ...              WVYM898J9W51CV
# payCardID                4677151756111287186  ...            3560745863909418
# payCardBank                           brizzi  ...                         dki
# payCardName        H. Xanana Santoso, S.Farm  ...          Dt. Warta Yuliarti
# payCardSex                                 M  ...                           M
# payCardBirthDate                        2010  ...                        1989
# corridorID                            JAK.15  ...                          7E
# corridorName      Bulak Turi - Tanjung Priok  ...  Kampung Rambutan - Ragunan
# direction                                0.0  ...                         0.0
# tapInStops                           B01327P  ...                     B05697P
# tapInStopsName                 Jln. Lorong 5  ...       Telkomsel Jln. Nangka
# tapInStopsLat                      -6.107716  ...                   -6.304254
# tapInStopsLon                       106.8955  ...                   106.84593
# stopStartSeq                              46  ...                          13
# tapInTime                2023-04-03 05:09:13  ...         2023-04-20 12:27:15
# tapOutStops                          B05728P  ...                      P00199
# tapOutStopsName            Term. Tj. Priok 1  ...                     Ragunan
# tapOutStopsLat                       -6.1098  ...                   -6.305769
# tapOutStopsLon                     106.88118  ...                   106.81949
# stopEndSeq                              52.0  ...                        21.0
# tapOutTime               2023-04-03 06:07:24  ...         2023-04-20 15:26:20
# payAmount                                0.0  ...                      3500.0
#
#                                          189491  \
# transID                          ERLW484O0H06UL
# payCardID                          630402756526
# payCardBank                               flazz
# payCardName       drg. Daniswara Winarno, S.Sos
# payCardSex                                    M
# payCardBirthDate                           2005
# corridorID                                   8A
# corridorName                  Jelambar - Juanda
# direction                                   1.0
# tapInStops                               P00176
# tapInStopsName                           Petojo
# tapInStopsLat                         -6.169984
# tapInStopsLon                         106.81698
# stopStartSeq                                  2
# tapInTime                   2023-04-04 05:33:13
# tapOutStops                              P00209
# tapOutStopsName                      RS Tarakan
# tapOutStopsLat                        -6.171146
# tapOutStopsLon                        106.81011
# stopEndSeq                                  3.0
# tapOutTime                  2023-04-04 05:53:25
# payAmount                                3500.0
#
#                                                189492  \
# transID                                QHPC294S1R67BW
# payCardID                            3527844683580632
# payCardBank                                       dki
# payCardName                           Karsana Gunawan
# payCardSex                                          F
# payCardBirthDate                                 1989
# corridorID                                        D21
# corridorName      Universitas Indonesia - Lebak Bulus
# direction                                         0.0
# tapInStops                                    B00402P
# tapInStopsName                   Gg. Ampera BMW Astra
# tapInStopsLat                               -6.292546
# tapInStopsLon                              106.790025
# stopStartSeq                                       23
# tapInTime                         2023-04-18 19:04:10
# tapOutStops                                   B02895P
# tapOutStopsName                          Poins Square
# tapOutStopsLat                              -6.289207
# tapOutStopsLon                              106.77718
# stopEndSeq                                       26.0
# tapOutTime                        2023-04-18 21:41:17
# payAmount                                      3500.0
#
#                                         189493  \
# transID                         DYOB765N0X83DF
# payCardID                     4477892629147428
# payCardBank                                dki
# payCardName                   Alambana Saputra
# payCardSex                                   M
# payCardBirthDate                          2007
# corridorID                                 12P
# corridorName      St. LRT Pegangsaan Dua - JIS
# direction                                  0.0
# tapInStops                             B00166P
# tapInStopsName     Boulevard Bukit Gading Raya
# tapInStopsLat                         -6.15515
# tapInStopsLon                        106.89579
# stopStartSeq                                 5
# tapInTime                  2023-04-03 20:38:52
# tapOutStops                                NaN
# tapOutStopsName           Jln. Sunter Permai 2
# tapOutStopsLat                       -6.131551
# tapOutStopsLon                       106.86248
# stopEndSeq                                14.0
# tapOutTime                 2023-04-03 21:48:16
# payAmount                               3500.0
#
#                                                   189494  \
# transID                                   GUCG964H1W85UJ
# payCardID                                213108168021420
# payCardBank                                       emoney
# payCardName                          Vanesa Aryani, M.M.
# payCardSex                                             M
# payCardBirthDate                                    1971
# corridorID                                        JAK.47
# corridorName      Pasar Minggu - Ciganjur via KB Ragunan
# direction                                            1.0
# tapInStops                                       B04002P
# tapInStopsName       Sbr. Madrasah Aliyah Citra Cendekia
# tapInStopsLat                                  -6.357553
# tapInStopsLon                                  106.80076
# stopStartSeq                                          47
# tapInTime                            2023-04-25 15:53:45
# tapOutStops                                      B05670P
# tapOutStopsName                       Tanah Baru Cipedak
# tapOutStopsLat                                 -6.363462
# tapOutStopsLon                                 106.80684
# stopEndSeq                                          50.0
# tapOutTime                           2023-04-25 16:27:31
# payAmount                                            0.0
#
#                                                       189495  \
# transID                                       AEQP180C2Q77IS
# payCardID                                    378254320267609
# payCardBank                                           emoney
# payCardName                       R.A. Malika Samosir, S.Kom
# payCardSex                                                 M
# payCardBirthDate                                        1998
# corridorID                                           JAK.43B
# corridorName      Tongtek - Tebet Eco Park (TEP) - Cililitan
# direction                                                1.0
# tapInStops                                           B06271P
# tapInStopsName                    Simpang Tebet Raya Timur 1
# tapInStopsLat                                      -6.229718
# tapInStopsLon                                      106.85286
# stopStartSeq                                              24
# tapInTime                                2023-04-02 13:00:49
# tapOutStops                                          B03318P
# tapOutStopsName                              Sawo Kecik Raya
# tapOutStopsLat                                     -6.224852
# tapOutStopsLon                                     106.85489
# stopEndSeq                                              34.0
# tapOutTime                               2023-04-02 14:54:30
# payAmount                                                0.0
#
#                                             189496  \
# transID                             PJOF006Z8Q63II
# payCardID                         5406087682675422
# payCardBank                                    dki
# payCardName                         Amalia Gunarto
# payCardSex                                       M
# payCardBirthDate                              1981
# corridorID                                      9C
# corridorName       Pinang Ranti - Bundaran Senayan
# direction                                      1.0
# tapInStops                                  P00040
# tapInStopsName    Cikoko Stasiun Cawang Arah Timur
# tapInStopsLat                            -6.243028
# tapInStopsLon                            106.85814
# stopStartSeq                                     9
# tapInTime                      2023-04-04 17:31:55
# tapOutStops                                 P00030
# tapOutStopsName         Cawang Ciliwung Arah Timur
# tapOutStopsLat                           -6.243012
# tapOutStopsLon                           106.86354
# stopEndSeq                                    10.0
# tapOutTime                     2023-04-04 18:38:31
# payAmount                                   3500.0
#
#                                        189497               189498  \
# transID                        NTSG621H8U49WW       PUNA543S2M10LX
# payCardID                 4674674527076302608        4952762933693
# payCardBank                            brizzi               online
# payCardName             R.A. Lintang Wibisono      Yunita Sitompul
# payCardSex                                  F                    F
# payCardBirthDate                         1998                 1984
# corridorID                                 6T                    2
# corridorName            Pasar Minggu - Velbak  Pulo Gadung - Monas
# direction                                 1.0                  1.0
# tapInStops                            B06746P               P00005
# tapInStopsName    Sbr. Jln. Pangeran Antasari                 ASMI
# tapInStopsLat                       -6.275209            -6.171797
# tapInStopsLon                      106.808665             106.8888
# stopStartSeq                               17                   12
# tapInTime                 2023-04-05 10:37:19  2023-04-14 13:34:20
# tapOutStops                           B06750P               P00192
# tapOutStopsName    Sbr. SDN Cilandak Barat 15        Pulo Gadung 1
# tapOutStopsLat                      -6.288628            -6.183239
# tapOutStopsLon                     106.806811            106.90907
# stopEndSeq                               19.0                 15.0
# tapOutTime                2023-04-05 12:20:28  2023-04-14 16:05:12
# payAmount                              3500.0               3500.0
#
#                                         189499
# transID                         NRUZ377L2D82PG
# payCardID                     2235668090485688
# payCardBank                                dki
# payCardName                        Omar Rahayu
# payCardSex                                   M
# payCardBirthDate                          1997
# corridorID                                  8C
# corridorName      Kebayoran Lama - Tanah Abang
# direction                                  1.0
# tapInStops                             B02196P
# tapInStopsName               Mall Thamrin City
# tapInStopsLat                        -6.194341
# tapInStopsLon                        106.81453
# stopStartSeq                                12
# tapInTime                  2023-04-29 09:14:32
# tapOutStops                            B05223P
# tapOutStopsName                      Simprug 1
# tapOutStopsLat                       -6.223678
# tapOutStopsLon                        106.7902
# stopEndSeq                                28.0
# tapOutTime                 2023-04-29 11:53:39
# payAmount                               3500.0
#
# [22 rows x 189500 columns]

# %%
df.dtypes
# Out:
# transID              object
# payCardID             int64
# payCardBank          object
# payCardName          object
# payCardSex           object
# payCardBirthDate      int64
# corridorID           object
# corridorName         object
# direction           float64
# tapInStops           object
# tapInStopsName       object
# tapInStopsLat       float64
# tapInStopsLon       float64
# stopStartSeq          int64
# tapInTime            object
# tapOutStops          object
# tapOutStopsName      object
# tapOutStopsLat      float64
# tapOutStopsLon      float64
# stopEndSeq          float64
# tapOutTime           object
# payAmount           float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def load_data():

    data = pd.read_csv(CSV_PATH)

# %%
df.isna().sum()
# Out:
# transID                 0
# payCardID               0
# payCardBank             0
# payCardName             0
# payCardSex              0
# payCardBirthDate        0
# corridorID           6980
# corridorName        13528
# direction               0
# tapInStops           7241
# tapInStopsName          0
# tapInStopsLat           0
# tapInStopsLon           0
# stopStartSeq            0
# tapInTime               0
# tapOutStops         12369
# tapOutStopsName      6720
# tapOutStopsLat       6720
# tapOutStopsLon       6720
# stopEndSeq           6720
# tapOutTime           6720
# payAmount            3718
# dtype: int64

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from datetime import datetime
import pandas as pd
# import requests
from sqlalchemy import create_engine, text


# ================== CONFIG ==================
DB_USER = "postgres"
DB_PASSWORD = "admin"
DB_HOST = "host.docker.internal"
DB_PORT = "5432"
DB_NAME = "etl_test"
SOURCE_CSV_PATH = "/opt/airflow/data/data_transjakarta_1.csv"
TABLE_NAME = "transjakarta_trx"


def extract_data_tj():

    df = pd.read_csv(SOURCE_CSV_PATH)
    df.to_csv("/opt/airflow/data/raw_tj.csv", index=False)
    print("Extract selesai")

def transform_data_tj():
    df = pd.read_csv("/opt/airflow/data/raw_tj.csv")

    #drop null values
    df = df.dropna()

    #convert date
    df['tapInTime'] = pd.to_datetime(df['tapInTime'])
    df['tapOutTime'] = pd.to_datetime(df['tapOutTime'])

    #save to clean csv
    df.to_csv("/opt/airflow/data/clean_tj.csv", index=False)


def load_data_tj():
    df = pd.read_csv("/opt/airflow/data/clean_tj.csv")

    engine = create_engine(
        f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
    )

    #append to table
    df.to_sql(TABLE_NAME, engine, if_exists="append", index=False)


with DAG(
    dag_id="transjakarta_csv_etl",
    start_date=datetime(2026, 1, 1),
    schedule_interval=None,
    catchup=False,
    tags=["etl", "transfrom", "postgres"]
)as dag:

    extract_data_tj_task = PythonOperator(
        task_id="extract_data_tj",
        python_callable=extract_data_tj
    )

    transform_data_tj_task = PythonOperator(
        task_id="transform_data_tj",
        python_callable=transform_data_tj
    )

    load_data_tj_task = PythonOperator(
        task_id="load_data_tj",
        python_callable=load_data_tj
    )
    
    extract_data_tj_task >> transform_data_tj_task >> load_data_tj_task
